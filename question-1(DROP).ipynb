# %%
import pandas as pd
import re
url = "/content/train.csv"
input=pd.read_csv(url)
#print(input.isnull().sum())
input.dropna(subset=['New_Price'], inplace=True)
input.dropna(subset=['Mileage'], inplace=True)
print(input.isnull().sum())
data.head()
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# dtype: int64
#     Unnamed: 0                               Name Location  Year  \
# 1            2                       Honda Jazz V  Chennai  2011
# 5            7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016
# 8           10                   Maruti Ciaz Zeta    Kochi  2018
# 13          15        Mitsubishi Pajero Sport 4X4    Delhi  2014
# 18          20                  BMW 3 Series 320d    Kochi  2014
#
#     Kilometers_Driven Fuel_Type Transmission Owner_Type Mileage   Engine  \
# 1               46000    Petrol       Manual      First      13  1199 CC
# 5               36000    Diesel    Automatic      First   11.36  2755 CC
# ...
